# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %%
homevalues = pd.read_csv("single_family_home_values.csv")

# %%
homevalues.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15000 entries, 0 to 14999
# Data columns (total 18 columns):
# id                 15000 non-null int64
# address            15000 non-null object
# city               15000 non-null object
# state              15000 non-null object
# zipcode            15000 non-null int64
# latitude           14985 non-null float64
# longitude          14985 non-null float64
# bedrooms           15000 non-null int64
# bathrooms          15000 non-null float64
# rooms              15000 non-null int64
# squareFootage      15000 non-null int64
# lotSize            15000 non-null int64
# yearBuilt          14999 non-null float64
# lastSaleDate       15000 non-null object
# lastSaleAmount     15000 non-null int64
# priorSaleDate      11173 non-null object
# priorSaleAmount    11287 non-null float64
# estimated_value    15000 non-null int64
# dtypes: float64(5), int64(8), object(5)
# memory usage: 2.1+ MB

# %%
#convert last sale date to dateTime

homevalues["lastSaleDate"] = pd.to_datetime(homevalues["lastSaleDate"])
homevalues["priorSaleDate"] = pd.to_datetime(homevalues["priorSaleDate"])

homevalues.describe()
# Out:
#                  id       zipcode      latitude     longitude      bedrooms  \
# count  1.500000e+04  15000.000000  14985.000000  14985.000000  15000.000000
# mean   5.176229e+07  80204.919467     39.740538   -104.964076      2.708400
# std    6.190876e+07      9.715263      0.023555      0.039788      0.897231
# min    1.433670e+05  80022.000000     39.614531   -105.108440      0.000000
# 25%    1.004802e+07  80205.000000     39.727634   -104.978737      2.000000
# 50%    2.563241e+07  80206.000000     39.748048   -104.957689      3.000000
# 75%    5.114222e+07  80207.000000     39.758214   -104.937522      3.000000
# max    3.209481e+08  80209.000000     39.888020   -104.830930     15.000000
#
#           bathrooms         rooms  squareFootage       lotSize     yearBuilt  \
# count  15000.000000  15000.000000   15000.000000   15000.00000  14999.000000
# mean       2.195067      6.164133    1514.504400    5820.76620   1929.517168
# ...

# %%
#save N/A Values for futher exploration

nadf = homevalues[homevalues.isna().any(axis=1)]

# %%
#drop N/A from main DF

homevalues.dropna(inplace = True)

# %%
#outliers

sns.boxplot(homevalues.estimated_value)

# %%
upperOutlierCutoff = homevalues["estimated_value"].quantile(0.90)

# %%
homevalues = homevalues[homevalues["estimated_value"] <= upperOutlierCutoff]
homevalues = homevalues[homevalues["lastSaleAmount"] <= upperOutlierCutoff]
homevalues.shape
sns.boxplot(homevalues.estimated_value)

# %%
homevalues.shape
# Out:
# (9941, 18)

# %%
homevalues.estimated_value.hist()

# %%
homevalues.zipcode.hist()

# %%
sns.pairplot(homevalues[["lastSaleAmount", "estimated_value", "zipcode"]], hue = "zipcode")
# Out:
# C:\Users\kndoa\Anaconda3\lib\site-packages\numpy\core\_methods.py:140: RuntimeWarning: Degrees of freedom <= 0 for slice
#   keepdims=keepdims)
# C:\Users\kndoa\Anaconda3\lib\site-packages\numpy\core\_methods.py:132: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# C:\Users\kndoa\Anaconda3\lib\site-packages\statsmodels\nonparametric\kde.py:487: RuntimeWarning: invalid value encountered in true_divide
#   binned = fast_linbin(X, a, b, gridsize) / (delta * nobs)
# C:\Users\kndoa\Anaconda3\lib\site-packages\statsmodels\nonparametric\kdetools.py:34: RuntimeWarning: invalid value encountered in double_scalars
#   FAC1 = 2*(np.pi*bw/RANGE)**2

# %%
sns.stripplot(x = homevalues.zipcode, y = homevalues.estimated_value)

# %%
sns.violinplot(x = homevalues.zipcode, y = homevalues.estimated_value)

# %%
homevalues.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9941 entries, 0 to 14996
# Data columns (total 18 columns):
# id                 9941 non-null int64
# address            9941 non-null object
# city               9941 non-null object
# state              9941 non-null object
# zipcode            9941 non-null int64
# latitude           9941 non-null float64
# longitude          9941 non-null float64
# bedrooms           9941 non-null int64
# bathrooms          9941 non-null float64
# rooms              9941 non-null int64
# squareFootage      9941 non-null int64
# lotSize            9941 non-null int64
# yearBuilt          9941 non-null float64
# lastSaleDate       9941 non-null datetime64[ns]
# lastSaleAmount     9941 non-null int64
# priorSaleDate      9941 non-null object
# priorSaleAmount    9941 non-null float64
# estimated_value    9941 non-null int64
# dtypes: datetime64[ns](1), float64(5), int64(8), object(4)
# memory usage: 1.8+ MB
